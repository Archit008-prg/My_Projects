# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv(r"C:\Users\pragy\Downloads\insurance.csv")
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
p=df.groupby("sex")
for i,j in p:
    print(i)
    # print(j)
# Out:
# female
# male

# %%
xp=df[(df["sex"]=="female") & (df["smoker"]=="yes")].head()
print(xp)
# Out:
#     age     sex    bmi  children smoker     region     charges
# 0    19  female  27.90         0    yes  southwest  16884.9240
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 23   34  female  31.92         1    yes  northeast  37701.8768
# 58   53  female  22.88         1    yes  southeast  23244.7902
# 64   20  female  22.42         0    yes  northwest  14711.7438

# %%
df[(df["sex"]=="female") & (df["smoker"]=="yes")].count()  #count() returns the non null values of the column after applying the condition
df[(df["sex"]=="female") & (df["smoker"]=="yes")].shape[0]
# shape[0] is used to count the no. as mentioned conditioned
# Out:
# 115

# %%
df[(df["sex"]=="male") & (df["bmi"]>=27.90)].shape[0]
# Out:
# 458

# %%
df[df["age"]<=18].shape[0]
# Out:
# 69

# %%
num_non_null_charges = df[(df["sex"] == "female") & (df["smoker"] == "yes")]
zz=num_non_null_charges["charges"].count()
print(num_non_null_charges )
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# 64     20  female  22.420         0    yes  northwest  14711.74380
# ...   ...     ...     ...       ...    ...        ...          ...
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [115 rows x 7 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
df["charges"].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
rt=df[df["smoker"]=="yes"].groupby("region")["smoker"].count()
rt
# for i,j in r:
#     print(i)
#     print(j)
# print(r)
# Out:
# region
# northeast    67
# northwest    58
# southeast    91
# southwest    58
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.plot(rt,label="No. of smokers in each region",color='y')
plt.xlabel("region")
plt.xlabel("smokers")
plt.legend(loc=2)
plt.show()

# %%
plt.scatter(df["age"], df["charges"],c="r")  #, cmap="viridis") 
# "c" parameter ka hona zaruri h taki cmap ka use ho ske...

# plt.colorbar(label="Smoker (yes=1, no=0)")

plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Scatter plot of Age vs Charges with Smoker Status")
plt.show()

# %%
df.head()

# %%
df[(df["bmi"]<=18) & (df["smoker"]=="yes")]
# df[(df["bmi"]<=18) & (df["smoker"]=="yes")].shape[0]

# %%
df[df["region"].str.contains("northwest")].head(10)

# %%
smoker_count = df["smoker"].value_counts()


# plt.bar(smoker_count.index, smoker_count.values, color="m")


# plt.xlabel("Smoker")
# plt.ylabel("Count")
# plt.title("Count of Smokers and Non-Smokers")

# plt.show()

print(smoker_count)

# %%
df.head()

# %% [markdown]
# linear regression

# %%
x=df[df["smoker"]=="no"]
# y=df[df["smoker"]=="yes"]
plt.scatter(x["age"],x["charges"],color="m")
# plt.scatter(y["age"],y["charges"])
plt.xlabel("Age of non-smokers")
plt.ylabel("Charges")
plt.show()
